# %% [markdown]
# # Template Django para Listagem de Tickets
# # Este notebook contém o template HTML para a página de listagem de

# %%
"""
{% extends 'base.html' %}
{% load static %}

{% block title %}Listagem de Tickets{% endblock %}

{% block content %}
<div class="container mt-4">
    <div class="row mb-4">
        <div class="col">
            <h1 class="display-5 fw-bold text-primary">
                <i class="bi bi-ticket-perforated-fill me-2"></i>Tickets
            </h1>
        </div>
        <div class="col-auto d-flex align-items-center">
            <a href="{% url 'ticket_criar' %}" class="btn btn-primary">
                <i class="bi bi-plus-circle me-2"></i>Novo Ticket
            </a>
        </div>
    </div>
    
    <div class="card shadow-sm">
        <div class="card-header bg-light">
            <div class="row">
                <div class="col-md-8">
                    <h5 class="mb-0">Tickets Cadastrados</h5>
                </div>
                <div class="col-md-4">
                    <form method="get" class="d-flex">
                        <input type="text" name="busca" class="form-control form-control-sm me-2" 
                               placeholder="Buscar tickets..." value="{{ request.GET.busca|default:'' }}">
                        <button type="submit" class="btn btn-sm btn-outline-secondary">
                            <i class="bi bi-search"></i>
                        </button>
                    </form>
                </div>
            </div>
        </div>
        <div class="card-body p-0">
            <div class="table-responsive">
                <table class="table table-hover mb-0">
                    <thead class="table-light">
                        <tr>
                            <th scope="col">#</th>
                            <th scope="col">Tipo</th>
                            <th scope="col">Empresa</th>
                            <th scope="col">Escritório</th>
                            <th scope="col">Nº Escritório</th>
                            <th scope="col">Criado por</th>
                            <th scope="col">Criado em</th>
                            <th scope="col">Prazo</th>
                            <th scope="col" class="text-center">Ações</th>
                        </tr>
                    </thead>
                    <tbody>
                        {% for ticket in tickets %}
                        <tr>
                            <td>{{ ticket.id }}</td>
                            <td><span class="badge bg-{{ ticket.tipo|default:'secondary' }}">{{ ticket.get_tipo_display }}</span></td>
                            <td>{{ ticket.nome_empresa }}</td>
                            <td>{{ ticket.escritorio }}</td>
                            <td>{{ ticket.numero_escritorio }}</td>
                            <td>{{ ticket.criado_por }}</td>
                            <td>{{ ticket.criado_em|date:"d/m/Y H:i" }}</td>
                            <td>
                                {% if ticket.prazo %}
                                <span class="{% if ticket.prazo|date:'Y-m-d' < hoje %}text-danger fw-bold{% endif %}">
                                    {{ ticket.prazo|date:"d/m/Y" }}
                                </span>
                                {% else %}
                                <span class="text-muted">Não definido</span>
                                {% endif %}
                            </td>
                            <td class="text-center">
                                <div class="btn-group btn-group-sm">
                                    <a href="{% url 'ticket_detalhar' ticket.id %}" class="btn btn-outline-info" 
                                       data-bs-toggle="tooltip" title="Visualizar">
                                        <i class="bi bi-eye"></i>
                                    </a>
                                    <a href="{% url 'ticket_editar' ticket.id %}" class="btn btn-outline-primary" 
                                       data-bs-toggle="tooltip" title="Editar">
                                        <i class="bi bi-pencil"></i>
                                    </a>
                                    <a href="{% url 'ticket_excluir' ticket.id %}" class="btn btn-outline-danger" 
                                       data-bs-toggle="tooltip" title="Excluir">
                                        <i class="bi bi-trash"></i>
                                    </a>
                                </div>
                            </td>
                        </tr>
                        {% empty %}
                        <tr>
                            <td colspan="9" class="text-center py-4">
                                <div class="text-muted">
                                    <i class="bi bi-inbox fs-2 d-block mb-2"></i>
                                    <p>Nenhum ticket encontrado</p>
                                    {% if request.GET.busca %}
                                    <a href="{% url 'ticket_listar' %}" class="btn btn-sm btn-outline-secondary">
                                        Limpar filtros
                                    </a>
                                    {% else %}
                                    <a href="{% url 'ticket_criar' %}" class="btn btn-sm btn-primary
